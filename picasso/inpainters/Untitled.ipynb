# %%
import cv2 
import pylab as pl

# %%
nparr = pl.load('/Users/peppe/work/inpainting_cmb/T_99.89973_-51.09838.npy')
pl.imshow((nparr )  );pl.colorbar() 
mask = pl.load('/Users/peppe/work/inpainting_cmb/stack_mask_128_128_10000.npy')

# %%
inputt = pl.load('/Users/peppe/work/picasso/picasso/input.npy')
pl.imshow( out   );pl.colorbar()

# %%
out =   pl.load('/Users/peppe/work/inpainting_cmb/T_99.89973_-51.09838_masked.npyT_255.82764_-18.49489_inpainted.npy')
pl.imshow((out - nparr ) /nparr   ) ;pl.colorbar()

# %%
inputt = pl.load('/Users/peppe/work/picasso/picasso/maskprocessed.npy')
pl.imshow(  inputt   );pl.colorbar()
